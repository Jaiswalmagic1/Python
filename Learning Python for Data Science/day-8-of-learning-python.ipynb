# %% [markdown]
# https://colab.research.google.com/drive/1D6Lywxl84Tx_fl6Td5MJhLivJM5bxCGn?usp=sharing

# %% [markdown]
# Functions, Introduction to Classes and Objects

# %% [markdown]
# **Lesson Plan Overview**
#
# Topics Covered:
#
#
#
# *  Functions in Python
# *  Introduction to Classes and Objects
# * Basic Object-Oriented Programming (OOP) Concepts
#
# Learning Objectives:
#
# * Understand the concept of reusable code using functions.
# * Grasp the fundamentals of classes and objects.
# * Apply basic OOP concepts to solve real-world problems.

# %% [markdown]
# ---
#
# 1. Functions in Python
#
#
# ---

# %% [markdown]
# **Definition**:
# A function is a block of code that performs a specific task and can be reused.
#
# **Syntax**:
#
#     def function_name(parameters):
#         # Code block
#         return value
#
# **Key Concepts**:
#
# * Parameters and Arguments
#
# * Return Statements
#
# * Scope of Variables

# %%
# function --- define and calling
def square():
  print(5**2)

square()
# Out:
# 25

# %%
# parameters or arguments
def square(a):
  return a**2

print(square(2))
print(square(5))
print(square(6))
# Out:
# 4
# 25
# 36

# %%
# wap to print average of 2 numbers
#  5, 6 = avg?
def avg(a,b):
  return (a+b)/2

print(avg(5,6))
# Out:
# 5.5

# %%
# even or odd
def even_odd(n):
  if n%2 == 0:
    return 'even'
  return 'Odd'

even_odd(8)
even_odd(5)
# Out:
# 'Odd'

# %% [markdown]
# # Lambda Function

# %%
# lambda parameter:expression
add = lambda x,y: x+y

print(add(2,2))
# Out:
# 4

# %%
# map function
# map() applies lambda x: x ** 2 to each item in numbers.


n = [1,2,3,4,5]
sq = list(map(lambda x:x**2 , n ))
print(sq)

# %%
# filter() – Select Items Based on Condition
n = [1,2,3,4,5]
a = filter(lambda x:x%2==0,n)
print(list(a))
# Out:
# [2, 4]

# %%
l=[1,2,3,4,5,6]

mul=list(map(lambda x:x*x, l))

# %%
# Function to calculate the factorial of a number:
# approach 1 5! = 5*4*3*2*1, 0! = 1, 1! = 1

def factorial(n):
  f = 1
  for i in range(1,n+1): #1,2,3,4,5
    f*=i                 #f = f*i
  return f

print(factorial(5))
# Out:
# 120

# %%
# Approach 2: #recursion = re + occuring
def fact(n):
  if n == 0 or n == 1:
    return 1
  return n*fact(n-1)

fact(5)
# Out:
# 120

# %%
# def fact(n):
#   # code1
#   # code2
#   # code3
#   n*fact(n-1)

# fact(5)

# %%
# Function with default parameters
def intro(name,age=27):
  print(f'my name is {name} and age is {age}')

intro('sneha',28)
# Out:
# my name is sneha and age is 28

# %%
# Activity:
# Write a function to check if a given number is prime.  range(2,3) = 1,2,3,4
def prime(a):
  if a>1:
    for i in range(2,a):#2
      if a%i == 0:
        return 'not prime'
    return 'prime'
  return 'enter values greater than 1'

prime(3)
# Out:
# 'not prime'

# %%
# Create a function to find the greatest of three numbers.
def greatest(a,b,c):
  return max(a,b,c)

greatest(1,4,3)
# Out:
# 4

# %%
g = lambda a,b,c: max(a,b,c)
g(1,2,3)
# Out:
# 3

# %% [markdown]
# ---
# 2. Introduction to Classes and Objects
#
#
# ---

# %% [markdown]
# **Definition**:
# A class is a blueprint for creating objects, which are instances of a class.
#
# **Syntax**:
#
#     class ClassName:
#         def __init__(self, parameters):
#             # Initialize attributes
#
#         def method_name(self):
#             # Code block
#
# **Key Concepts**:
#
# * Attributes (variables in a class)
#
# * Methods (functions in a class)
#
# * __init__ Method (Constructor)

# %%
class intro:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def display(self):
    print(f'My name is {self.name} and i am {self.age} years old')


test = intro('sneha',23)
test.display()
# Out:
# My name is sneha and i am 23 years old

# %%
# Create a class Book with attributes title, author, and price, and a method to display book details.

class book:
    def __init__(self,title, author, price):
        self.title = title
        self.author = author
        self.price = price

    def display(self):
        print(f'book name is {self.title}, it is written by {self.author} and price is {self.price}')

aboa = book('Autobiography of a Yogi', 'Shishya', 220)

aboa.display()
# Out:
# book name is Autobiography of a Yogi, it is written by Shishya and price is 220

# %%
class book:
    def __init__(self,title, author, price):
        self.title = input('Please enter the title name')
        self.author = input('Please enter the authot name')
        self.price = int(input('Please enter the price'))

    def display(self):
        print(f'book name is {self.title}, it is written by {self.author} and price is {self.price}')

aboa = book('Autobiography of a Yogi', 'Shishya', 220)

aboa.display()
# Out:
# Please enter the title name hello
# Please enter the authot name me
# Please enter the price 20
# book name is hello, it is written by me and price is 20

# %%
# Write a program to create an object representing a car and include methods like start and stop.

# %%
# syntax
# class class_name:
#   def __init__(self,variables):
#     self.var1 = variables

#   def method_name(self):
#     print(self.var1)

# obj = class_name("xyz")
# obj.method_name()

# %% [markdown]
# ---
# 3. Basic OOP Concepts
#
#
# ---

# %% [markdown]
# **Encapsulation**:
# Wrapping data and methods into a single unit (class).
#
# **Inheritance**:
# Deriving a new class from an existing class to reuse and extend functionality.
#
# **Polymorphism**:
# Using a single interface to represent different types.

# %% [markdown]
# ### Practice

# %% [markdown]
# 1. Basic Function Definition
# * Write a function greet that takes a name as input and returns a greeting message in the format:
#
#
#
# ```
# # greet("Alice")  # Output: "Hello, Alice!"
# ```

# %%
name = input('Enter your name: ')

print(f'Hello, {name}!')
# Out:
# Enter your name:  Vishal
# Hello, Vishal!

# %% [markdown]
# 2. Function with Default Arguments
# * Define a function power(base, exponent=2) that returns the base raised
# to the exponent.
#
# Example usage:
#
#
# ```
# power(3)      # Output: 9  (since default exponent is 2)
# power(2, 3)   # Output: 8
#
# ```

# %%
def power(a,b=2):
    print(a**b)

# %%
power(2, 3)
# Out:
# 8

# %% [markdown]
# 3. Lambda Function for Sorting
# * You have a list of tuples representing students and their marks:
#
#
# ```
# students = [("Alice", 85), ("Bob", 78), ("Charlie", 92), ("David", 88)]
#
# ```
# Sort the list in descending order of marks using a lambda function inside the sorted() function.

# %%
# students = [ x : x]

# %%
students = [("Alice", 85), ("Bob", 78), ("Charlie", 92), ("David", 88)]

# %% [markdown]
# 4. Lambda Function for squaring the numbers in the list
#
#
#
# ```
# expected output
# n = [1,4,9,16,25]
# ```

# %% [markdown]
# 5. Lambda Function for Filtering
# * You have a list of numbers
#
# ```
# numbers = [10, 25, 33, 40, 55, 60, 75]
# ```
# Use the filter() function with a lambda to extract only the numbers that are divisible by 5.

# %%
# Activity:

# Create a base class Shape with a method to calculate the area, and derive two classes Circle and Rectangle from it.

# Write a program demonstrating polymorphism with a parent class Animal and derived classes Dog and Cat.
