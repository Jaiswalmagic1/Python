# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading dataset
emp = pd.read_csv('/kaggle/input/employee-data/employee_data.csv')

emp.head()
# Out:
#    ID  Age  Gender Department    Salary  Years_of_Experience  \
# 0   1   56    Male  Marketing  22776.90                    9
# 1   2   46  Female         IT  79045.84                   21
# 2   3   32    Male         HR  61131.24                   12
# 3   4   60  Female    Finance  52811.30                   15
# 4   5   25  Female         IT  70440.11                    2
#
#    Performance_Score Work_Location Joining_Date  Hours_Worked_Per_Week
# 0                  4        Office   2010-01-01                     37
# 1                  9        Office   2010-01-02                     31
# 2                  2        Office   2010-01-03                     47
# 3                  3        Office   2010-01-04                     59
# 4                 10        Hybrid   2010-01-05                     26

# %%
emp.describe(include='all')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                  ID          Age  Gender Department        Salary  \
# count   1000.000000  1000.000000    1000       1000   1000.000000
# unique          NaN          NaN       3          5           NaN
# top             NaN          NaN  Female    Finance           NaN
# freq            NaN          NaN     491        220           NaN
# mean     500.500000    40.986000     NaN        NaN  51235.957340
# std      288.819436    13.497852     NaN        NaN  15265.528212
# min        1.000000    18.000000     NaN        NaN   6065.730000
# 25%      250.750000    29.000000     NaN        NaN  41292.222500
# 50%      500.500000    42.000000     NaN        NaN  51755.930000
# 75%      750.250000    52.000000     NaN        NaN  60976.652500
# max     1000.000000    64.000000     NaN        NaN  98907.370000
#
#         Years_of_Experience  Performance_Score Work_Location Joining_Date  \
# count           1000.000000        1000.000000          1000         1000
# unique                  NaN                NaN             3         1000
# top                     NaN                NaN        Office   2010-01-01
# freq                    NaN                NaN           519            1
# mean              12.785000           5.584000           NaN          NaN
# std                6.759324           2.913663           NaN          NaN
# min                1.000000           1.000000           NaN          NaN
# 25%                7.000000           3.000000           NaN          NaN
# 50%               13.000000           6.000000           NaN          NaN
# 75%               19.000000           8.000000           NaN          NaN
# max               24.000000          10.000000           NaN          NaN
#
#         Hours_Worked_Per_Week
# count             1000.000000
# unique                    NaN
# top                       NaN
# freq                      NaN
# mean                39.398000
# std                 11.493463
# min                 20.000000
# 25%                 30.000000
# 50%                 39.000000
# 75%                 49.000000
# max                 59.000000

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Salary                 1000 non-null   float64
#  5   Years_of_Experience    1000 non-null   int64
#  6   Performance_Score      1000 non-null   int64
#  7   Work_Location          1000 non-null   object
#  8   Joining_Date           1000 non-null   object
#  9   Hours_Worked_Per_Week  1000 non-null   int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 78.2+ KB

# %%
emp = emp.drop(columns='ID')

# %%
emp.head()
# Out:
#    Age  Gender Department    Salary  Years_of_Experience  Performance_Score  \
# 0   56    Male  Marketing  22776.90                    9                  4
# 1   46  Female         IT  79045.84                   21                  9
# 2   32    Male         HR  61131.24                   12                  2
# 3   60  Female    Finance  52811.30                   15                  3
# 4   25  Female         IT  70440.11                    2                 10
#
#   Work_Location Joining_Date  Hours_Worked_Per_Week
# 0        Office   2010-01-01                     37
# 1        Office   2010-01-02                     31
# 2        Office   2010-01-03                     47
# 3        Office   2010-01-04                     59
# 4        Hybrid   2010-01-05                     26

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    1000 non-null   int64
#  1   Gender                 1000 non-null   object
#  2   Department             1000 non-null   object
#  3   Salary                 1000 non-null   float64
#  4   Years_of_Experience    1000 non-null   int64
#  5   Performance_Score      1000 non-null   int64
#  6   Work_Location          1000 non-null   object
#  7   Joining_Date           1000 non-null   object
#  8   Hours_Worked_Per_Week  1000 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 70.4+ KB

# %%
emp['Joining_Date'] = pd.to_datetime(emp['Joining_Date'])

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    1000 non-null   int64
#  1   Gender                 1000 non-null   object
#  2   Department             1000 non-null   object
#  3   Salary                 1000 non-null   float64
#  4   Years_of_Experience    1000 non-null   int64
#  5   Performance_Score      1000 non-null   int64
#  6   Work_Location          1000 non-null   object
#  7   Joining_Date           1000 non-null   datetime64[ns]
#  8   Hours_Worked_Per_Week  1000 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(3)
# memory usage: 70.4+ KB

# %%
emp.columns
# Out:
# Index(['Age', 'Gender', 'Department', 'Salary', 'Years_of_Experience',
#        'Performance_Score', 'Work_Location', 'Joining_Date',
#        'Hours_Worked_Per_Week'],
#       dtype='object')

# %% [markdown]
# #Matplot lib Visualization

# %%
# line plot
# shows trends over time
# example: salary trend over joining dates

plt.figure(figsize=(12,6))
filtered_df = emp[emp['Joining_Date'].dt.year.isin([2011])]
df_sorted = emp.sort_values(by='Joining_Date')
plt.plot(df_sorted['Joining_Date'], df_sorted['Salary'], color='orange', marker = 'o')
plt.xlabel('Joining_date')
plt.ylabel('Salary')
plt.title('Salary Trend in 2012')
plt.show()

# %%
# Sort the data by date
df_sorted = emp.sort_values(by='Joining_Date')

# Extract year from the joining date
df_sorted['year'] = df_sorted['Joining_Date'].dt.year

# Group by year and calculate average salary
yearly_data = df_sorted.groupby('year')['Salary'].mean().reset_index()

# Plot the trend
plt.figure(figsize=(7, 5))
plt.plot(yearly_data['year'], yearly_data['Salary'], color='green', marker='*', linewidth=2)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Salary', fontsize=12)
plt.title('📈 Average Salary Trend Over the Years', fontsize=14)
plt.xticks(yearly_data['year'])
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-f277f4474878>:18: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(7,5))

df_sorted = emp.sort_values(by='Joining_Date')

df_sorted['year'] = df_sorted['Joining_Date'].dt.year

yearly_data = df_sorted.groupby('year')['Salary'].mean().reset_index()

plt.plot(yearly_data['year'], yearly_data['Salary'], color = 'green', marker='*')
plt.xlabel('Year')
plt.ylabel('Salary')
plt.title('Average Salary Trend Overall')
plt.xticks(yearly_data['year'])
plt.show()

# %%
# bar plot
# comparing categories
# example : average salary by department
plt.figure(figsize = (12,6))

dep_grouped = emp.groupby('Department')['Salary'].mean().reset_index()

plt.bar(dep_grouped['Department'], dep_grouped['Salary'], color='green')

plt.xlabel('Department')
plt.ylabel('Salary')
plt.title('Department wise average salary')

dep_grouped
# Out:
#   Department        Salary
# 0    Finance  51415.879227
# 1         HR  51124.937943
# 2         IT  51159.029799
# 3  Marketing  50448.043238
# 4      Sales  52055.427347

# %%
emp
# Out:
#      Age  Gender Department    Salary  Years_of_Experience  Performance_Score  \
# 0     56    Male  Marketing  22776.90                    9                  4
# 1     46  Female         IT  79045.84                   21                  9
# 2     32    Male         HR  61131.24                   12                  2
# 3     60  Female    Finance  52811.30                   15                  3
# 4     25  Female         IT  70440.11                    2                 10
# ..   ...     ...        ...       ...                  ...                ...
# 995   22    Male    Finance  62807.13                   15                  5
# 996   40    Male         HR  41666.87                    9                  3
# 997   27  Female    Finance  36924.83                    8                 10
# 998   61    Male         IT  47064.82                   20                  9
# 999   19    Male      Sales  72180.85                    1                  6
#
#     Work_Location Joining_Date  Hours_Worked_Per_Week
# 0          Office   2010-01-01                     37
# 1          Office   2010-01-02                     31
# 2          Office   2010-01-03                     47
# 3          Office   2010-01-04                     59
# 4          Hybrid   2010-01-05                     26
# ..            ...          ...                    ...
# 995        Office   2012-09-22                     21
# 996        Hybrid   2012-09-23                     41
# 997        Office   2012-09-24                     39
# 998        Remote   2012-09-25                     52
# 999        Office   2012-09-26                     27
#
# [1000 rows x 9 columns]

# %%
# Scatter Plot
# Purpose: Show relationships between two numerical variables
# Example: Salary vs Performance Score

plt.figure(figsize=(12,6))
plt.scatter(emp['Years_of_Experience'], emp['Salary'])
plt.xlabel('Department')
plt.ylabel()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-16a422e1f65a> in <cell line: 8>()
#       6 plt.scatter(emp['Years_of_Experience'], emp['Salary'])
#       7 plt.xlabel('Department')
# ----> 8 plt.ylabel()
#
# TypeError: ylabel() missing 1 required positional argument: 'ylabel'

# %%
emp.head()
# Out:
#    Age  Gender Department    Salary  Years_of_Experience  Performance_Score  \
# 0   56    Male  Marketing  22776.90                    9                  4
# 1   46  Female         IT  79045.84                   21                  9
# 2   32    Male         HR  61131.24                   12                  2
# 3   60  Female    Finance  52811.30                   15                  3
# 4   25  Female         IT  70440.11                    2                 10
#
#   Work_Location Joining_Date  Hours_Worked_Per_Week
# 0        Office   2010-01-01                     37
# 1        Office   2010-01-02                     31
# 2        Office   2010-01-03                     47
# 3        Office   2010-01-04                     59
# 4        Hybrid   2010-01-05                     26

# %%
# pie chart
# show proportions
# work location distribution
wl = emp['Work_Location'].value_counts()

plt.pie(wl, labels= wl.index, autopct='%1.1f%%', explode=[0,0.1,.1], colors = ['Pink', 'Hotpink', 'Magenta'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7afd141b4eb0>,
#   <matplotlib.patches.Wedge at 0x7afd141b5d50>,
#   <matplotlib.patches.Wedge at 0x7afd1420f460>],
#  [Text(-0.0656202821455366, 1.0980409730839467, 'Office'),
#   Text(-0.6269983159775061, -1.023168173743384, 'Remote'),
#   Text(0.983942518842263, -0.6869185684011919, 'Hybrid')],
#  [Text(-0.03579288117029268, 0.5989314398639708, '51.9%'),
#   Text(-0.3657490176535452, -0.5968481013503072, '28.7%'),
#   Text(0.5739664693246533, -0.4007024982340286, '19.4%')])

# %%
# Histogram
# Purpose: Show data distribution
# Example: Age distribution

plt.figure(figsize = (8,5))

plt.hist(emp['Age'], bins=10, color='cyan', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Count of emp')
plt.title('Number of employees in age groups')
# Out:
# Text(0.5, 1.0, 'Number of employees in age groups')

# %%
# 6. Box Plot
# Purpose: Summarize distributions and detect outliers
# Example: Salary distribution by work location
plt.figure(figsize=(8,4))
emp.boxplot(column = 'Salary', by= 'Work_Location', grid=False)
# Out:
# <Axes: title={'center': 'Salary'}, xlabel='Work_Location'>

# %%
# 7. Heatmap
# Purpose: Show correlations
# Example: Correlation matrix for numerical features

numerical_df = emp.select_dtypes(include=[np.number])
numerical_df.corr()

sns.heatmap(numerical_df.corr(), annot=True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
emp = pd.read_csv('/kaggle/input/employee-data/employee_data.csv')
emp.head()
emp.describe(include='all')
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Salary                 1000 non-null   float64
#  5   Years_of_Experience    1000 non-null   int64
#  6   Performance_Score      1000 non-null   int64
#  7   Work_Location          1000 non-null   object
#  8   Joining_Date           1000 non-null   object
#  9   Hours_Worked_Per_Week  1000 non-null   int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 78.2+ KB

# %%
# Convert to datetime (fixing the root issue)
emp['Joining_Date'] = pd.to_datetime(emp['Joining_Date'], errors='coerce')

# Drop rows where date conversion failed (optional but safe)
emp.dropna(subset=['Joining_Date'], inplace=True)

# Filter for 2011 joiners
filtered_df = emp[emp['Joining_Date'].dt.year == 2011]

# Sort for line plot
df_sorted = filtered_df.sort_values(by='Joining_Date')

# Plot
plt.figure(figsize=(12,6))
plt.plot(df_sorted['Joining_Date'], df_sorted['Salary'], color='orange', marker='o')
plt.xlabel('Joining Date')
plt.ylabel('Salary')
plt.title('Salary Trend in 2011')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_sorted['year'] = df_sorted['Joining_Date'].dt.year
yearly_data = df_sorted.groupby('year')['Salary'].mean().reset_index()

plt.figure(figsize=(7,5))
plt.plot(yearly_data['year'], yearly_data['Salary'], color='green', marker='*')
plt.xlabel('Year')
plt.ylabel('Salary')
plt.title('Average Salary Trend Overall')
plt.xticks(yearly_data['year'])
plt.show()

# %%
dep_grouped = emp.groupby('Department')['Salary'].mean().reset_index()

plt.figure(figsize=(12,6))
plt.bar(dep_grouped['Department'], dep_grouped['Salary'], color='green')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.title('Department wise average salary')
plt.show()

# %%
# Ensure Joining_Date is properly formatted
emp['Joining_Date'] = pd.to_datetime(emp['Joining_Date'], errors='coerce')
emp.dropna(subset=['Joining_Date'], inplace=True)

# Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=emp, x='Age', y='Salary', hue='Department', palette='Set2', alpha=0.8)

# Customizations
plt.title('🧑‍💼 Age vs Salary by Department', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Salary', fontsize=12)
plt.legend(title='Department', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-12-158f28704900>:15: UserWarning: Glyph 129489 (\N{ADULT}) missing from current font.
#   plt.tight_layout()
# <ipython-input-12-158f28704900>:15: UserWarning: Glyph 128188 (\N{BRIEFCASE}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129489 (\N{ADULT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128188 (\N{BRIEFCASE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,5))
sns.histplot(emp['Salary'], kde=True, color='skyblue')
plt.title('Distribution of Salaries')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Department', y='Salary', data=emp)
plt.title('Salary Distribution by Department')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Age', y='Salary', data=emp, hue='Department')
plt.title('Age vs Salary by Department')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Department', data=emp, palette='viridis')
plt.title('Number of Employees in Each Department')
plt.xticks(rotation=45)
plt.show()
